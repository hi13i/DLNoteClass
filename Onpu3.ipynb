# %% [markdown]
# <a href="https://colab.research.google.com/github/hi13i/DLNoteClass/blob/master/Onpu3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16027, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 16027 (delta 3), reused 11 (delta 1), pack-reused 16008
# Receiving objects: 100% (16027/16027), 14.61 MiB | 27.56 MiB/s, done.
# Resolving deltas: 100% (11014/11014), done.

# %%
# !unzip /content/Onpu3_test.v2i.yolov5pytorch.zip
# Out:
# unzip:  cannot find or open /content/Onpu3_test.v2i.yolov5pytorch.zip, /content/Onpu3_test.v2i.yolov5pytorch.zip.zip or /content/Onpu3_test.v2i.yolov5pytorch.zip.ZIP.

# %%
# %cd /content/yolov5/
# !pip install -qr requirements.txt
# %cd /content/Onpu640/
# !unzip "640"
# %cd /content/yolov5/
# Out:
# /content/yolov5
# /content/Onpu640
# Archive:  640.zip
# replace README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: nA
# replace data.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: An
#  extracting: data.yaml
#  extracting: train/images/02_0_0_jpg.rf.2b47cdd1f3407965363c1cd14550555e.jpg
#  extracting: train/images/02_0_0_jpg.rf.5958fe7f45fea14c79e65eeb8f1b8c11.jpg
#  extracting: train/images/02_0_0_jpg.rf.9c51964bba29b04a9199c62b44c31891.jpg
#  extracting: train/images/02_0_1_jpg.rf.d5f06f83163f6fd121b8676d15d54a0e.jpg
#  extracting: train/images/02_0_2_jpg.rf.460fd99276a874d528ea6876e72cb6da.jpg
#  extracting: train/images/02_0_2_jpg.rf.89b37449f1d27d18226b55ea2541c69f.jpg
#  extracting: train/images/02_0_2_jpg.rf.ade74c590a92d14ec6a35df0c86e4159.jpg
#  extracting: train/images/02_1_1_jpg.rf.83e1d3337b33454afb8c4256e8bb4cf9.jpg
#  extracting: train/images/02_1_2_jpg.rf.737393cf6f27bdb99dde0c8bafd558c6.jpg
# ...

# %% [markdown]
# ↓エラーが出たらdata.yamlのパスを相対パスから絶対パスに書き換える

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data {"/content/Onpu640/data.yaml"} --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/Onpu640/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-189-ga453a45 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --source {"/content/result/"} --weights {"/content/yolov5/runs/train/exp9/weights/best.pt" } --conf 0.25 --name trained_exp --exist-ok --save-conf
# Out:
# detect: weights=['/content/yolov5/runs/train/exp9/weights/best.pt'], source=/content/result/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=trained_exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-189-ga453a45 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/result/out_2_2_3.jpg: 640x640 11 flatss, 56 notess, 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 4.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/trained_exp

# %% [markdown]
# # SAHIのてすと
